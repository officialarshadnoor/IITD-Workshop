# %% [markdown]
# <a href="https://colab.research.google.com/github/officialarshadnoor/IITD-Workshop/blob/main/Deepface_Day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Install DeepFace Library
# !pip install deepface
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.7/87.7 kB 2.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 11.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.3/88.3 kB 11.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.2/80.2 kB 10.2 MB/s eta 0:00:00
# ...
#   Created wheel for fire: filename=fire-0.5.0-py2.py3-none-any.whl size=116934 sha256=5243eade63292d8a7578507739a1b9b50ef2d75fb8141aa388054c5af04e9391
#   Stored in directory: /root/.cache/pip/wheels/90/d4/f7/9404e5db0116bd4d43e5666eaa3e70ab53723e1e3ea40c9a95
# Successfully built fire
# ...

# %%
#Import DeepFace, CV2 and Matplotlib libraries
from deepface import DeepFace
import cv2
import matplotlib.pyplot as plt
# Out:
# 24-02-18 04:42:43 - Directory /root/.deepface created
# 24-02-18 04:42:43 - Directory /root/.deepface/weights created

# %%
#Download a file
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-7043add1-df18-405c-a64a-bfefa712f7c1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7043add1-df18-405c-a64a-bfefa712f7c1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
check_img = cv2.imread('Capture_1.JPG')
plt.figure(figsize=(7,7))
plt.imshow(check_img[:, :, ::-1])

# %%
# deepface analyse the uploaded image
analyze_face = DeepFace.analyze(check_img)
# Out:
# Action: emotion:   0%|          | 0/4 [00:00<?, ?it/s]
# 24-02-18 04:45:30 - facial_expression_model_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/facial_expression_model_weights.h5
# To: /root/.deepface/weights/facial_expression_model_weights.h5
#
#   0%|          | 0.00/5.98M [00:00<?, ?B/s]
#  18%|█▊        | 1.05M/5.98M [00:00<00:00, 7.56MB/s]
#  44%|████▍     | 2.62M/5.98M [00:00<00:00, 10.8MB/s]
# 100%|██████████| 5.98M/5.98M [00:00<00:00, 14.3MB/s]
# Action: age:  25%|██▌       | 1/4 [00:02<00:06,  2.07s/it]
# 24-02-18 04:45:36 - age_model_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/age_model_weights.h5
# To: /root/.deepface/weights/age_model_weights.h5
#
#   0%|          | 0.00/539M [00:00<?, ?B/s]
#   0%|          | 1.05M/539M [00:00<00:55, 9.78MB/s]
#   0%|          | 2.62M/539M [00:00<00:42, 12.5MB/s]
# ...

# %%
# print all analysis of an image
analyze_face
# Out:
# [{'emotion': {'angry': 13.228347810703777,
#    'disgust': 0.060611018903357516,
#    'fear': 14.267776695754922,
#    'happy': 0.0005308318399536885,
#    'sad': 71.29924043426031,
#    'surprise': 0.0014210727510882428,
#    'neutral': 1.1420673260608523},
#   'dominant_emotion': 'sad',
#   'region': {'x': 115, 'y': 56, 'w': 158, 'h': 158},
#   'face_confidence': 6.120618123037275,
#   'age': 31,
#   'gender': {'Woman': 99.9150037765503, 'Man': 0.08499628747813404},
#   'dominant_gender': 'Woman',
#   'race': {'asian': 0.43882476165890694,
#    'indian': 0.4559295251965523,
#    'black': 0.035893486347049475,
#    'white': 72.6001501083374,
#    'middle eastern': 13.010258972644806,
#    'latino hispanic': 13.458941876888275},
#   'dominant_race': 'white'}]

# %%
analyze_face['dominant_emotion']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-722a006f031d> in <cell line: 1>()
# ----> 1 analyze_face['dominant_emotion']
#
# TypeError: list indices must be integers or slices, not str
